# %%
# Storing the URL as a variable
data_url = 'https://raw.githubusercontent.com/Soumyoj/ML-AI-Python/main/TX%20Schools%20-%20August%202020.csv'

# %%
# Loading the data science related pandas package
import pandas as pd

# %%
# Reading the data from the url  and assigning a variable
df = pd.read_csv(data_url)
# Displaying content of the data
df
# Display rows and columns
df.shape
# Out:
# (1998, 24)

# %%
# Loading the dataprep package 
# !pip install dataprep
# Out:
# ...
#      |████████████████████████████████| 9.5 MB 11.8 MB/s
# ...
#      |████████████████████████████████| 965 kB 49.5 MB/s
# ...
#      |████████████████████████████████| 943 kB 36.3 MB/s
# ...
#      |████████████████████████████████| 1.5 MB 43.1 MB/s
# ...
#      |████████████████████████████████| 749 kB 22.4 MB/s
# ...
#      |████████████████████████████████| 50 kB 7.4 MB/s
# ...
#      |████████████████████████████████| 95 kB 4.8 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 40.8 MB/s
# ...
#      |████████████████████████████████| 10.9 MB 55.8 MB/s
# ...
#      |████████████████████████████████| 366 kB 58.0 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 58.6 MB/s
# ...
#      |████████████████████████████████| 132 kB 48.1 MB/s
# ...
#      |████████████████████████████████| 78 kB 8.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 144 kB 54.5 MB/s
# ...

# %%
# importing eda report code from dataprep
from dataprep.eda import create_report

# %%
# Saving the eda report
create_report(df).save()
# Out:
# Report has been saved to /content/report.html!
